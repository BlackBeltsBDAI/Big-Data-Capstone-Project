# %%
import pandas as pd
import datetime

# %%
url_22='https://drive.google.com/file/d/1U7ayxEZqurdGlf8VqAcZsURiFLW0l5G3/view?usp=sharing'
url_22='https://drive.google.com/uc?id=' + url_22.split('/')[-2]
df_22 = pd.read_csv(url_22)
# #-------------------------------------------------------------------------------------------
url_21='https://drive.google.com/file/d/18QYZjL5atz5AXTnIrWHkQ9Y7PADWRBa0/view?usp=sharing'
url_21='https://drive.google.com/uc?id=' + url_21.split('/')[-2]
df_21 = pd.read_csv(url_21)
#-------------------------------------------------------------------------------------------
url_20='https://drive.google.com/file/d/11nmJ0VMoUt3JuQ4nYjW41R31f9U7L1xK/view?usp=sharing'
url_20='https://drive.google.com/uc?id=' + url_20.split('/')[-2]
df_20 = pd.read_csv(url_20)
# #-------------------------------------------------------------------------------------------
url_19='https://drive.google.com/file/d/13WWcynmDl448cNK50WDA1sh3OLblUIkG/view?usp=sharing'
url_19='https://drive.google.com/uc?id=' + url_19.split('/')[-2]
df_19 = pd.read_csv(url_19)
# #-------------------------------------------------------------------------------------------
url_18='https://drive.google.com/file/d/1O1BFAy6Gnz9wBHUEqt_AxjwLflsOnS9l/view?usp=sharing'
url_18='https://drive.google.com/uc?id=' + url_18.split('/')[-2]
df_18 = pd.read_csv(url_18)
# #-------------------------------------------------------------------------------------------
url_17='https://drive.google.com/file/d/1-dkY46sAiOOkOSXbQ61Z7ktB60I7ftZR/view?usp=sharing'
url_17='https://drive.google.com/uc?id=' + url_17.split('/')[-2]
df_17 = pd.read_csv(url_17)
# -------------------------------------------------------------------------------------------
url_16='https://drive.google.com/file/d/1Sfj5GPuM9D8ApdJx_3y4wFPdQYUpOiki/view?usp=sharing'
url_16='https://drive.google.com/uc?id=' + url_16.split('/')[-2]
df_16 = pd.read_csv(url_16)

# %%
df_22.shape

# %%
df_21.shape

# %%
df_20.shape

# %%
df_19.shape

# %%
df_18.shape

# %%
df_17.shape

# %%
df_16.shape

# %%
df = pd.concat([df_22,df_21,df_20,df_19,df_18,df_17,df_16])

# %% [markdown]
# ### Basic Exploration

# %%
# number of rows and columns
df.shape

# %%
# quick overview on data
df.info()

# %%
# list of columns' name 
df.columns

# %%
# check if there is null values in each column
df.isna().sum()

# %%
df.dropna(inplace=True)

# %%
# check the unique values in each column
df.nunique()

# %%
# basic descriptive statistics for numerical features 
df.describe()

# %%
# basic descriptive statistics for categorical features
df.describe(include='O')

# %%
# df2=pd.read_csv('/content/drive/MyDrive/BD & AI/week14/Data/Data.csv')

# %%
df.isna().sum()

# %%
# chech the duplication recored
df.drop_duplicates().sum()

# %%
# Drop duplicate rows in place
df.drop_duplicates(inplace=True)

# %%
df['Year'].unique()

# %%
df['Date']

# %%
df['Month'] = pd.DatetimeIndex(df['Date']).month
df['Day'] = pd.DatetimeIndex(df['Date']).day
df['Hour'] = pd.DatetimeIndex(df['Date']).hour
df['Minute'] = pd.DatetimeIndex(df['Date']).minute
df['AM/PM'] = pd.to_datetime(df['Date']).dt.strftime('%p')
df.head()

# %%
df.columns

# %%
df.to_csv('/content/drive/MyDrive/BD & AI/week14/Data/Data.csv',index=None)
